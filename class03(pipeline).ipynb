# %% [markdown]
# - multilclass -> softmax
# - 크면 클 수록 성능차이 늘어난다.
# #### queue runners
# - 다 밀어 넣고 out of range error 발생
# - ETL (데이터 전처리, transform, loading)

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import os
# %matplotlib inline

# %% [markdown]
# ### 디멘션 문제
# - (r, c, 1) <--> (r, c)
# - reduce_mean( , axis=-1) -> 뒤에 1 사라진다.
# - expand_dim( , axis=-1) -> 다시 뒤에 1 만들어 준다.

# %%
tf.reset_default_graph()
image_dir = './tfrecord_dataset/images_png'
label_name = './tfrecord_dataset/label_csv/label.csv'
image_names = [os.path.join(image_dir, n) for n in os.listdir(image_dir)]
image_names = sorted(image_names)

#shuffle 지금 하면 라벨과 매칭이 안된다. = False
img_name_queue = tf.train.string_input_producer(image_names, shuffle=False, num_epochs=1)
lable_name_queue = tf.train.string_input_producer([label_name], shuffle=False, num_epochs=1)

img_reader = tf.WholeFileReader()
label_reader = tf.TextLineReader()

key, value = img_reader.read(img_name_queue)
txt_key, txt_value = label_reader.read(lable_name_queue)

# 이미지로 보기위해 decoding
img_png = tf.image.decode_png(value)
img_png = tf.reduce_mean(img_png, axis = -1)
img_png = tf.reshape(img_png, [-1])# 모든원소가 1차원으로 펼쳐진다.

label_csv = tf.decode_csv(txt_value, record_defaults=[[0]])

with tf.Session() as sess:
    sess.run(tf.local_variables_initializer())
    coord = tf.train.Coordinator()
    thread = tf.train.start_queue_runners(sess, coord)
    
    face_train_dir = './cnn_dataset/face_train.tfrecord'
    face_test_dir = './cnn_dataset/face_test.tfrecord'
    
    train_writer = tf.python_io.TFRecordWriter(face_train_dir)
    test_writer = tf.python_io.TFRecordWriter(face_test_dir)
    
    for i in range(9999999999999):
        try:
            _img, _label = sess.run([img_png, label_csv])

            example = tf.train.Example()
            example.features.feature['age'].int64_list.value.append(_label[0])#append : value값으로 
            example.features.feature['img'].int64_list.value.extend(_img.tolist())# extend : 리스트형태
            train_writer.write(example.SerializeToString())
            print('{}th record is written'.format(i))
            
        except tf.errors.OutOfRangeError:
            print('end of redcord')
            break
            
    train_writer.close()
        
    coord.request_stop()
    coord.join(thread)
# Out:
# 0th record is written
# 1th record is written
# 2th record is written
# 3th record is written
# 4th record is written
# 5th record is written
# 6th record is written
# 7th record is written
# 8th record is written
# 9th record is written
# 10th record is written
# 11th record is written
# 12th record is written
# 13th record is written
# 14th record is written
# 15th record is written
# 16th record is written
# 17th record is written
# 18th record is written
# 19th record is written
# 20th record is written
# 21th record is written
# 22th record is written
# 23th record is written
# 24th record is written
# 25th record is written
# 26th record is written
# 27th record is written
# 28th record is written
# 29th record is written
# 30th record is written
# 31th record is written
# 32th record is written
# 33th record is written
# 34th record is written
# 35th record is written
# 36th record is written
# 37th record is written
# 38th record is written
# 39th record is written
# ...
